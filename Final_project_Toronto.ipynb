# %% [markdown]
# # Market research for opening restaurant in Toronto
#
# ### Introduction / Business Problem
#
# Toronto along with being the financial capital of Canada and a city of great diversity is the provincial capital of Ontario and the most populous city in Canada. With a population of 2.7 million, and 6 million within the Greater Toronto Area, Toronto offers an interesting market for the restaurant business. The aim of this study is to determine which kind of restaurant to open there and to find a suitable location for doing so.
#
# The type of restaurant to be opened will be the type of restaurant which has the highest average evaluation among Foursquare users. Based on this decision a suitable location for the new restaurant will be sought by looking for a location which best meets the following criteria:
#
# 1. The close vicinity does not yet contain the selected type of restaurant (in order to avoid unnecessary competition)
# 2. The nearest current restaurants have low ratings (in order to find competition easier to beat)
# 3. There are many rather than few restaurants near the location (the number of restaurants is used as a proxy for the number of potential customers, locations with high numbers of restaurants should also be rich with potential clients)
#
# ### Data
#
# The project will be based on Foursquare data drawn from its API. The dataset will comprise of 50 restaurants in downtown Toronto (specified as latitude = 43.651070, longitude = -79.347015).

# %%
import pandas as pd
import numpy as np
import math
import json
import getpass
import time
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import folium # map rendering library

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Settings for Foursquare API

CLIENT_ID = getpass.getpass(prompt='CLIENT_ID: ')
CLIENT_SECRET = getpass.getpass(prompt='CLIENT_SECRET: ')
VERSION = '20180605'
LIMIT = '100'
radius = '500'
# Out:
# CLIENT_ID: ········
# CLIENT_SECRET: ········

# %%
# Toronto
latitude = 43.651070
longitude = -79.347015

print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&query=restaurant&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude,
            LIMIT)
# Out:
# 43.65107 -79.347015

# %%
results = requests.get(url).json()

# %% [markdown]
# #### Send the GET Request and examine the results
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)

# %%
print(dataframe.shape)
dataframe
# Out:
# (50, 19)
#                           id                                            name  \
# 0   5d3127c715cfea0007e44d52                                  est Restaurant
# 1   4ae77362f964a52069ab21e3                                Mi Mi Restaurant
# 2   4ad4c05cf964a520e1f520e3               Docks Restaurant & Night Club The
# 3   4ada5d5bf964a520e92121e3                  The Hot House Restaurant & Bar
# 4   4ad4c05cf964a52006f620e3                           Victoria's Restaurant
# 5   4ae094a7f964a5208f8021e3                               SCHOOL Restaurant
# 6   4ad4c060f964a5207bf720e3        Gio Rana's Really Really Nice Restaurant
# 7   4b7b268cf964a52061542fe3                          Tender Trap Restaurant
# 8   4ad4c05cf964a520cef520e3  Sassafraz | Cafe | Restaurant | Private Events
# 9   4ad4c060f964a5207ff720e3                          Rol San Restaurant 龍笙棧
# 10  4bd47e6fcfa7b7139f2924da                               Studio Restaurant
# 11  4ad4c05ff964a52018f720e3                     Cottage Restaurant & Lounge
# 12  4b072e9df964a52009f922e3              Sky Dragon Chinese Restaurant 龍翔酒樓
# 13  4b02a076f964a520234922e3                           ONE Restaurant/Lounge
# 14  5c33c7cd8194fc002c66f72e                   Green Tea Restaurant Downtown
# 15  4f872713e4b0abaa00979185                 Site Of Great Canary Restaurant
# 16  4ad4c05cf964a520cdf520e3                  Insomnia Restaurant and Lounge
# 17  4b266f05f964a520657b24e3                  Goldstone Noodle Restaurant 金石
# 18  4ad4c05cf964a520dff520e3                                  360 Restaurant
# 19  4ba2d00cf964a5203e1b38e3                        Ka Chi Korean Restaurant
# 20  4d0fb7b7a3d9721e0fb1d0fd                       Red Chili Thai Restaurant
# 21  4ae29812f964a520288f21e3                         Swatow Restaurant 汕頭小食家
# 22  4b223f5af964a520ba4424e3                          Azure Restaurant & Bar
# 23  4c6345c358810f477c71091e                   Sunshine Caribbean Restaurant
# 24  59719d3c65211f46b1172eb2             Caribbean Sunset Restaurant and Bar
# 25  4bc3ad5e461576b0db037f32                           Sightlines Restaurant
# 26  4bce1ec0cc8cd13a9ac8c3cf               Kensington Cornerstone Restaurant
# 27  576c61e5498ef74633413b66                                  Lan Restaurant
# 28  4aef8854f964a5201cd921e3                    Aroma Fine Indian Restaurant
# 29  5750b013498e755287c6de97              Some Time BBQ Grill Restaurant 碳烤屋
# 30  4b0c6669f964a5207e3c23e3                               Makkah Restaurant
# 31  587bae87286804584acd2a7a                  Isabella’s Boutique Restaurant
# 32  4b19c8b7f964a52017e423e3            Sunrise House Korean Restaurant 해뜨는집
# 33  5e1f32b49dfc69000731470f                     Abugida Restaurant & Lounge
# 34  4ad4c05ff964a52048f720e3                 Hemispheres Restaurant & Bistro
# 35  4b074bb1f964a52077fb22e3                        New Sky Restaurant 小沙田食家
# 36  4ada6d8df964a520832221e3                                Union Restaurant
# 37  4b22e814f964a520175024e3                         The Lakeview Restaurant
# 38  4b9fcc3df964a520a43f37e3                Imonay House Restaurant 뉴 · 이모네집
# 39  4b4d3b51f964a520e4ce26e3                      Matisse Restaurant And Bar
# 40  5b1c3098f96b2c002c5eb0c5         Tasty's Caribbean Restaurant & Catering
# 41  4d06c1ccc2e53704428cc567              North-East Chinese Restaurant 華北美食
# 42  4c47d78c1ddec92817ca9e32                   Micheal's Restaurant and Deli
# 43  4ad4c05df964a5203ff620e3                         Victor Restaurant & Bar
# 44  5a60f513a6031c579d573413                 Mapo Korean BBQ Restaurant 마포상회
# 45  4dd5555245ddd703552b6c67                 Lim Ga Ne Korean Restaurant 임가네
# 46  4dbda6034df044e52500bb8d                            Via Norte Restaurant
# 47  4be8b576d837c9b6e2b6a506                Makkalchon Korean Restaurant 맛깔촌
# 48  4b11b1f2f964a520778223e3                       Korean Village Restaurant
# 49  4bf96c435317a593a23a017f     Karaikudi Chettinad South Indian Restaurant
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1598811115    False
# 1   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1598811115    False
# 2   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1598811115    False
# 3   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1598811115    False
# 4   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 5   [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1598811115    False
# 6   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1598811115    False
# 7   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1598811115    False
# 8   [{'id': '4bf58dd8d48988d171941735', 'name': 'E...  v-1598811115    False
# 9   [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1598811115    False
# 10  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1598811115    False
# 11  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1598811115    False
# 12  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1598811115    False
# 13  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...  v-1598811115    False
# 14  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1598811115    False
# 15  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1598811115    False
# 16  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 17  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...  v-1598811115    False
# 18  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1598811115    False
# 19  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 20  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1598811115    False
# 21  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1598811115    False
# 22  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 23  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1598811115    False
# 24  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 25  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1598811115    False
# 26  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1598811115    False
# 27  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1598811115    False
# 28  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1598811115    False
# 29  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1598811115    False
# 30  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 31  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1598811115    False
# 32  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 33  [{'id': '4bf58dd8d48988d10a941735', 'name': 'E...  v-1598811115    False
# 34  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1598811115    False
# 35  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1598811115    False
# 36  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...  v-1598811115    False
# 37  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1598811115    False
# 38  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 39  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 40  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1598811115    False
# 41  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1598811115    False
# 42  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1598811115    False
# 43  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1598811115    False
# 44  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 45  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 46  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1598811115    False
# 47  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 48  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1598811115    False
# 49  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1598811115    False
#
#                    location.address  location.lat  location.lng  \
# 0                729 Queen St. East     43.658911    -79.349035
# 1           688 Gerrard Street East     43.666293    -79.349079
# 2                     11 Polson St.     43.641806    -79.354171
# 3                      35 Church St     43.648824    -79.373702
# 4               37 King Street East     43.649298    -79.376431
# 5                    70 Fraser Ave.     43.637775    -79.424297
# 6                   1220 Queen St E     43.663367    -79.330425
# 7                 580 Parliament St     43.667724    -79.369485
# 8             100 Cumberland Street     43.670342    -79.391041
# 9                  323 Spadina Ave.     43.654318    -79.398650
# 10                   389 Church St.     43.661500    -79.379319
# 11                   338 Jarvis St.     43.662770    -79.376894
# 12                 280 Spadina Ave.     43.652783    -79.398174
# 13                116 Yorkville Ave     43.670809    -79.393272
# 14  261 Spadina Avenue. Upper level     43.652488    -79.397501
# 15                              NaN     43.653323    -79.357883
# 16                563 Bloor St West     43.665180    -79.410966
# 17                  266 Spadina Ave     43.652278    -79.398039
# 18                   301 Front St W     43.642537    -79.387042
# 19                  8 St Andrew St.     43.654307    -79.399277
# 20               1266 Danforth Ave.     43.681934    -79.330622
# 21                 309 Spadina Ave.     43.653866    -79.398334
# 22                   225 Front St W     43.644749    -79.385113
# 23                 937 Danforth Ave     43.680767    -79.338146
# 24                  753A Queen St E     43.659348    -79.347954
# 25                    Rogers Centre     43.641635    -79.389365
# 26               2A Kensington Ave.     43.652803    -79.399958
# 27                              NaN     43.659234    -79.348055
# 28                   287 King St. W     43.646463    -79.389644
# 29               988 Baldwin Street     43.655874    -79.393826
# 30                    1020 danforth     43.680642    -79.336613
# 31                  2328 Queen St E     43.673767    -79.282703
# 32            661 Bloor Street West     43.664183    -79.415746
# 33                1393 Danforth Ave     43.682305    -79.327641
# 34              110 Chestnut Street     43.654884    -79.385931
# 35                 353 Spadina Ave.     43.655337    -79.398897
# 36                72 Ossington Ave.     43.645860    -79.419532
# 37                1132 Dundas St. W     43.649435    -79.420390
# 38                   665 Bloor St W     43.664123    -79.415815
# 39                     90 Bloor St.     43.670574    -79.384856
# 40                  405 Spadina Ave     43.656794    -79.399251
# 41                   476 Dundas St.     43.653185    -79.396677
# 42                   566 Queen St W     43.647289    -79.403493
# 43                 30 Mercer Street     43.645634    -79.391125
# 44                   680 Bloor St W     43.664096    -79.416738
# 45                  686 Bloor St. W     43.663945    -79.416882
# 46               938 College Street     43.653732    -79.426303
# 47             1979 Lawrence Ave. E     43.744945    -79.296494
# 48            628 Bloor Street West     43.664498    -79.414367
# 49                  1225 Kennedy Rd     43.756042    -79.276276
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 43.658911, 'lng':...                887
# 1   [{'label': 'display', 'lat': 43.66629336492295...               1702
# 2   [{'label': 'display', 'lat': 43.64180568910036...               1181
# 3   [{'label': 'display', 'lat': 43.64882370529773...               2164
# 4   [{'label': 'display', 'lat': 43.64929834396347...               2377
# 5   [{'label': 'display', 'lat': 43.6377753703417,...               6398
# 6   [{'label': 'display', 'lat': 43.66336657355032...               1912
# 7   [{'label': 'display', 'lat': 43.66772379650776...               2590
# 8   [{'label': 'display', 'lat': 43.67034226367314...               4144
# 9   [{'label': 'display', 'lat': 43.65431754076345...               4174
# 10  [{'label': 'display', 'lat': 43.66150015906530...               2849
# 11  [{'label': 'display', 'lat': 43.66277006654972...               2736
# 12  [{'label': 'display', 'lat': 43.65278331265585...               4124
# 13  [{'label': 'display', 'lat': 43.67080936827553...               4324
# 14  [{'label': 'display', 'lat': 43.65248783033554...               4069
# 15  [{'label': 'display', 'lat': 43.65332280645853...                910
# 16  [{'label': 'display', 'lat': 43.66517961801332...               5384
# 17  [{'label': 'display', 'lat': 43.6522783893466,...               4111
# 18  [{'label': 'display', 'lat': 43.64253731714456...               3361
# 19  [{'label': 'display', 'lat': 43.65430655228665...               4224
# 20  [{'label': 'display', 'lat': 43.68193429383672...               3680
# 21  [{'label': 'display', 'lat': 43.65386562507761...               4145
# 22  [{'label': 'display', 'lat': 43.64474919591934...               3148
# 23  [{'label': 'display', 'lat': 43.680767, 'lng':...               3382
# 24  [{'label': 'display', 'lat': 43.659347534, 'ln...                924
# 25  [{'label': 'display', 'lat': 43.64163507221119...               3569
# 26  [{'label': 'display', 'lat': 43.65280330843737...               4268
# 27  [{'label': 'display', 'lat': 43.659234, 'lng':...                912
# 28  [{'label': 'display', 'lat': 43.64646252150344...               3471
# 29  [{'label': 'display', 'lat': 43.655874, 'lng':...               3808
# 30  [{'label': 'display', 'lat': 43.68064246148289...               3396
# 31  [{'label': 'display', 'lat': 43.673767, 'lng':...               5762
# 32  [{'label': 'display', 'lat': 43.66418287914217...               5724
# 33  [{'label': 'display', 'lat': 43.68230487165694...               3810
# 34  [{'label': 'display', 'lat': 43.65488413420439...               3163
# 35  [{'label': 'display', 'lat': 43.65533674412141...               4205
# 36  [{'label': 'display', 'lat': 43.64585979013257...               5869
# 37  [{'label': 'display', 'lat': 43.64943515996231...               5912
# 38  [{'label': 'display', 'lat': 43.66412292954772...               5728
# 39  [{'label': 'display', 'lat': 43.67057375344845...               3741
# 40  [{'label': 'display', 'lat': 43.656794, 'lng':...               4255
# 41  [{'label': 'display', 'lat': 43.6531846832903,...               4006
# 42  [{'label': 'display', 'lat': 43.64728932229506...               4568
# 43  [{'label': 'display', 'lat': 43.64563436248102...               3604
# 44  [{'label': 'display', 'lat': 43.66409588590324...               5799
# 45  [{'label': 'display', 'lat': 43.66394504978582...               5806
# 46  [{'label': 'display', 'lat': 43.653732, 'lng':...               6393
# 47  [{'label': 'display', 'lat': 43.74494499908732...              11213
# 48  [{'label': 'display', 'lat': 43.66449791303206...               5626
# 49  [{'label': 'display', 'lat': 43.75604153945313...              12998
#
#    location.postalCode location.cc location.city location.state  \
# 0              M4M 1H1          CA       Toronto             ON
# 1              M4M 1Y3          CA       Toronto             ON
# 2              M5A 1A4          CA       Toronto             ON
# 3              M5E 1T3          CA       Toronto             ON
# 4              M5C 1E9          CA       Toronto             ON
# 5              M6K 3C5          CA       Toronto             ON
# 6              M4M 1L7          CA       Toronto             ON
# 7              M4X 1P8          CA       Toronto             ON
# 8              M5R 1A6          CA       Toronto             ON
# 9              M5T 2E9          CA       Toronto             ON
# 10                 M5B          CA       Toronto             ON
# 11             M4Y 2G6          CA       Toronto             ON
# 12                 NaN          CA       Toronto             ON
# 13                 NaN          CA       Toronto             ON
# 14             M5T 2E3          CA       Toronto             ON
# 15                 NaN          CA           NaN            NaN
# 16             M5S 1Y6          CA       Toronto             ON
# 17             M5T 2E4          CA       Toronto             ON
# 18             M5V 2T6          CA       Toronto             ON
# 19             M5T 1K6          CA       Toronto             ON
# 20                 NaN          CA       Toronto             ON
# 21             M5T 2E6          CA       Toronto             ON
# 22             M5V 2X3          CA       Toronto             ON
# 23                 NaN          CA       Toronto             ON
# 24             M4M 1H3          CA       Toronto             ON
# 25                 NaN          CA       Toronto             ON
# 26             M5T 2J7          CA       Toronto             ON
# 27                 NaN          CA           NaN            NaN
# 28             M5V 1J5          CA       Toronto             ON
# 29                 NaN          CA       Toronto             ON
# 30                 NaN          CA       Toronto             ON
# 31                 NaN          CA       Toronto             ON
# 32                 NaN          CA       Toronto             ON
# 33             M4J 1N2          CA       Toronto             ON
# 34             M5G 1R3          CA       Toronto             ON
# 35             M5T 2G3          CA       Toronto             ON
# 36                 NaN          CA       Toronto             ON
# 37             M6J 1X2          CA       Toronto             ON
# 38             M6G 1L1          CA       Toronto             ON
# 39             M4W 1A7          CA       Toronto             ON
# 40             M5T 2G6          CA       Toronto             ON
# 41                 NaN          CA       Toronto             ON
# 42                 NaN          CA       Toronto             ON
# 43             M5V 1H3          CA       Toronto             ON
# 44             M6G 1L2          CA       Toronto             ON
# 45                 M6G          CA       Toronto             ON
# 46                 NaN          CA       Toronto             ON
# 47                 NaN          CA       Toronto             ON
# 48                 NaN          CA       Toronto             ON
# 49             M1P 4Y1          CA       Toronto             ON
#
#    location.country                          location.formattedAddress  \
# 0            Canada   [729 Queen St. East, Toronto ON M4M 1H1, Canada]
# 1            Canada  [688 Gerrard Street East (at De Grassi St.), T...
# 2            Canada  [11 Polson St. (at Cherry), Toronto ON M5A 1A4...
# 3            Canada  [35 Church St (at Front St E), Toronto ON M5E ...
# 4            Canada  [37 King Street East (at Le Meridien King Edwa...
# 5            Canada  [70 Fraser Ave. (at Liberty St.), Toronto ON M...
# 6            Canada      [1220 Queen St E, Toronto ON M4M 1L7, Canada]
# 7            Canada  [580 Parliament St (at Wellesley St), Toronto ...
# 8            Canada  [100 Cumberland Street (Bellair St), Toronto O...
# 9            Canada  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 10           Canada  [389 Church St. (at Carlton St.), Toronto ON M...
# 11           Canada  [338 Jarvis St. (north of Carlton Street), Tor...
# 12           Canada  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 13           Canada  [116 Yorkville Ave (at Hazelton Ave.), Toronto...
# 14           Canada  [261 Spadina Avenue. Upper level, Toronto ON M...
# 15           Canada                                           [Canada]
# 16           Canada  [563 Bloor St West (Bathurst St), Toronto ON M...
# 17           Canada  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 18           Canada  [301 Front St W (301 Front St. W), Toronto ON ...
# 19           Canada  [8 St Andrew St. (at Spadina Ave.), Toronto ON...
# 20           Canada  [1266 Danforth Ave. (at Greenwood Ave.), Toron...
# 21           Canada  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 22           Canada  [225 Front St W (in InterContinental Toronto C...
# 23           Canada  [937 Danforth Ave (Donlands Ave), Toronto ON, ...
# 24           Canada      [753A Queen St E, Toronto ON M4M 1H3, Canada]
# 25           Canada                [Rogers Centre, Toronto ON, Canada]
# 26           Canada  [2A Kensington Ave. (Dundas St. W), Toronto ON...
# 27           Canada                                           [Canada]
# 28           Canada  [287 King St. W (at John St.), Toronto ON M5V ...
# 29           Canada           [988 Baldwin Street, Toronto ON, Canada]
# 30           Canada                [1020 danforth, Toronto ON, Canada]
# 31           Canada              [2328 Queen St E, Toronto ON, Canada]
# 32           Canada  [661 Bloor Street West (Manning), Toronto ON, ...
# 33           Canada  [1393 Danforth Ave (Monarch Park Ave), Toronto...
# 34           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 35           Canada     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 36           Canada  [72 Ossington Ave. (Queen St. W), Toronto ON, ...
# 37           Canada  [1132 Dundas St. W (at Ossington Ave.), Toront...
# 38           Canada  [665 Bloor St W (at Manning Ave), Toronto ON M...
# 39           Canada  [90 Bloor St. (Yonge St.), Toronto ON M4W 1A7,...
# 40           Canada  [405 Spadina Ave (College St), Toronto ON M5T ...
# 41           Canada       [476 Dundas St. (Huron), Toronto ON, Canada]
# 42           Canada               [566 Queen St W, Toronto ON, Canada]
# 43           Canada  [30 Mercer Street (at John St), Toronto ON M5V...
# 44           Canada       [680 Bloor St W, Toronto ON M6G 1L2, Canada]
# 45           Canada          [686 Bloor St. W, Toronto ON M6G, Canada]
# 46           Canada           [938 College Street, Toronto ON, Canada]
# 47           Canada  [1979 Lawrence Ave. E (Warden Ave.), Toronto O...
# 48           Canada        [628 Bloor Street West, Toronto ON, Canada]
# 49           Canada  [1225 Kennedy Rd (at Forbes (Between Lawrence ...
#
#    venuePage.id                        location.crossStreet  \
# 0     552734373                                         NaN
# 1           NaN                            at De Grassi St.
# 2           NaN                                   at Cherry
# 3           NaN                               at Front St E
# 4     498556908            at Le Meridien King Edward Hotel
# 5      38118429                              at Liberty St.
# 6           NaN                                         NaN
# 7           NaN                             at Wellesley St
# 8           NaN                                  Bellair St
# 9           NaN                               at D'Arcy St.
# 10          NaN                              at Carlton St.
# 11          NaN                     north of Carlton Street
# 12          NaN                            at Dundas St. W.
# 13          NaN                            at Hazelton Ave.
# 14          NaN                                         NaN
# 15          NaN                                         NaN
# 16     51631703                                 Bathurst St
# 17          NaN                              at Willison Sq
# 18          NaN                             301 Front St. W
# 19          NaN                             at Spadina Ave.
# 20          NaN                           at Greenwood Ave.
# 21          NaN              btwn Dundas St. W & D'Arcy St.
# 22    136175835          in InterContinental Toronto Centre
# 23          NaN                                Donlands Ave
# 24          NaN                                         NaN
# 25          NaN                                         NaN
# 26          NaN                                Dundas St. W
# 27          NaN                                         NaN
# 28          NaN                                 at John St.
# 29          NaN                                         NaN
# 30          NaN                                         NaN
# 31          NaN                                         NaN
# 32          NaN                                     Manning
# 33          NaN                            Monarch Park Ave
# 34          NaN                                         NaN
# 35          NaN                                         NaN
# 36          NaN                                 Queen St. W
# 37          NaN                           at Ossington Ave.
# 38          NaN                              at Manning Ave
# 39     83923512                                   Yonge St.
# 40          NaN                                  College St
# 41          NaN                                       Huron
# 42          NaN                                         NaN
# 43          NaN                                  at John St
# 44          NaN                                         NaN
# 45          NaN                                         NaN
# 46          NaN                                         NaN
# 47          NaN                                 Warden Ave.
# 48          NaN                                         NaN
# 49     33638214  at Forbes (Between Lawrence and Ellesmere)
#
#         location.neighborhood
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                   Yorkville
# 9           Kensington Market
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22     Entertainment District
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# 30                        NaN
# 31                The Beaches
# 32                        NaN
# 33  The Danforth, Toronto, ON
# 34                        NaN
# 35                        NaN
# 36                        NaN
# 37                        NaN
# 38                  Koreatown
# 39                        NaN
# 40                        NaN
# 41                        NaN
# 42                        NaN
# 43                        NaN
# 44                  Koreatown
# 45                        NaN
# 46                        NaN
# 47                        NaN
# 48                        NaN
# 49                        NaN

# %%
category_id = []
category_name = []

for x in range(len(dataframe)):
    category_id.append(dataframe['categories'][x][0].get('id', ''))
    category_name.append(dataframe['categories'][x][0].get('name', ''))

print('The restaurant categories are:\n', category_name)
# Out:
# ['Italian Restaurant', 'Chinese Restaurant', 'Thai Restaurant', 'Korean Restaurant', 'Bar', 'Caribbean Restaurant', 'Indian Restaurant', 'American Restaurant', 'Breakfast Spot', 'Dim Sum Restaurant', 'Wine Bar', 'Ethiopian Restaurant', 'Vietnamese Restaurant', 'Diner', 'Japanese Restaurant', 'New American Restaurant', 'Event Space', 'Noodle House', 'Szechuan Restaurant', 'Restaurant']

# %%
print('The dataset consists of', len(category_id), 'restaurants.')
print('There are', len(set(category_id)), 'different types of restaurants in the data.')
# Out:
# The dataset consists of 50 restaurants.
# There are 20 different types of restaurants in the data.

# %%
# Lists for storing information from venues
r_name = []
r_latitude = []
r_longitude = []
r_rating = []
r_ratingSignals = []
r_type = []
r_shortName = []

# %%
for i in dataframe['id']:
    
    # While loop to enable retrial if bad response
    while True:

        # Init retrial counter
        j = 0

        try:

            # create the API request URL
            temp_url_venue = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(
                i, # venue_id,
                CLIENT_ID, # self.client_id,
                CLIENT_SECRET, #self.client_secret,
                VERSION) # Settings.version)
    
            print(i)
    
            temp_response_venue = requests.get(temp_url_venue).json()
    
            # print(temp_response_venue)
    
            r_name.append(temp_response_venue['response']['venue'].get('name', ''))
            r_latitude.append(temp_response_venue['response']['venue']['location'].get('lat', np.nan))
            r_longitude.append(temp_response_venue['response']['venue']['location'].get('lng', np.nan))
            r_rating.append(temp_response_venue['response']['venue'].get('rating', np.nan))
            r_ratingSignals.append(temp_response_venue['response']['venue'].get('ratingSignals', np.nan))
            r_type.append(temp_response_venue['response']['venue']['categories'][0].get('name', ''))
            r_shortName.append(temp_response_venue['response']['venue']['categories'][0].get('shortName', ''))
    
    
            # Sleep long enough to ensure compliance with Foursquare API guidelines
            time.sleep(0.51)

        except:
            # Sleep long enough to ensure compliance with Foursquare API guidelines
            time.sleep(0.51)

            # Add to retrial counter
            j += 1
            print('Retrial ' + str(j))

            # Get back to while loop = retrial
            continue

        # Break the while loop if successful
        break
# Out:
# 5d3127c715cfea0007e44d52
# 4ae77362f964a52069ab21e3
# 4ad4c05cf964a520e1f520e3
# 4ada5d5bf964a520e92121e3
# 4ad4c05cf964a52006f620e3
# 4ae094a7f964a5208f8021e3
# 4ad4c060f964a5207bf720e3
# 4b7b268cf964a52061542fe3
# 4ad4c05cf964a520cef520e3
# 4ad4c060f964a5207ff720e3
# 4bd47e6fcfa7b7139f2924da
# 4ad4c05ff964a52018f720e3
# 4b072e9df964a52009f922e3
# 4b02a076f964a520234922e3
# 5c33c7cd8194fc002c66f72e
# 4f872713e4b0abaa00979185
# 4ad4c05cf964a520cdf520e3
# 4b266f05f964a520657b24e3
# 4ad4c05cf964a520dff520e3
# 4ba2d00cf964a5203e1b38e3
# 4d0fb7b7a3d9721e0fb1d0fd
# 4ae29812f964a520288f21e3
# 4b223f5af964a520ba4424e3
# 4c6345c358810f477c71091e
# 59719d3c65211f46b1172eb2
# 4bc3ad5e461576b0db037f32
# 4bce1ec0cc8cd13a9ac8c3cf
# 576c61e5498ef74633413b66
# 4aef8854f964a5201cd921e3
# 5750b013498e755287c6de97
# 4b0c6669f964a5207e3c23e3
# 587bae87286804584acd2a7a
# 4b19c8b7f964a52017e423e3
# 5e1f32b49dfc69000731470f
# 4ad4c05ff964a52048f720e3
# 4b074bb1f964a52077fb22e3
# 4ada6d8df964a520832221e3
# 4b22e814f964a520175024e3
# 4b9fcc3df964a520a43f37e3
# 4b4d3b51f964a520e4ce26e3
# 5b1c3098f96b2c002c5eb0c5
# 4d06c1ccc2e53704428cc567
# 4c47d78c1ddec92817ca9e32
# 4ad4c05df964a5203ff620e3
# 5a60f513a6031c579d573413
# 4dd5555245ddd703552b6c67
# 4dbda6034df044e52500bb8d
# 4be8b576d837c9b6e2b6a506
# 4b11b1f2f964a520778223e3
# 4bf96c435317a593a23a017f

# %% [markdown]
# ### Methodology
#
# Now that the restaurant data has been gathered the data will be aggregated by restaurant type, and mean ratings for the types of restaurants will be counted. The type of restaurant which has the highest mean rating will be decided to open. Lastly the restaurants will be placed on a map to scout a suitable place to open the new restaurant.

# %%
restaurant_data = {'Name': r_name, 
                   'Latitude': r_latitude,
                   'Longitude': r_longitude,
                   'Rating': r_rating,
                   'N': r_ratingSignals,
                   'Type': r_type,
                   'Short': r_shortName}

df_restaurants = pd.DataFrame(data=restaurant_data)
df_restaurants
# Out:
#                                               Name   Latitude  Longitude  \
# 0                                   est Restaurant  43.658911 -79.349035
# 1                                 Mi Mi Restaurant  43.666293 -79.349079
# 2                Docks Restaurant & Night Club The  43.641806 -79.354171
# 3                   The Hot House Restaurant & Bar  43.648824 -79.373702
# 4                            Victoria's Restaurant  43.649298 -79.376431
# 5                                SCHOOL Restaurant  43.637775 -79.424297
# 6         Gio Rana's Really Really Nice Restaurant  43.663367 -79.330425
# 7                           Tender Trap Restaurant  43.667724 -79.369485
# 8   Sassafraz | Cafe | Restaurant | Private Events  43.670342 -79.391041
# 9                           Rol San Restaurant 龍笙棧  43.654318 -79.398650
# 10                               Studio Restaurant  43.661500 -79.379319
# 11                     Cottage Restaurant & Lounge  43.662770 -79.376894
# 12              Sky Dragon Chinese Restaurant 龍翔酒樓  43.652783 -79.398174
# 13                           ONE Restaurant/Lounge  43.670809 -79.393272
# 14                   Green Tea Restaurant Downtown  43.652488 -79.397501
# 15                 Site Of Great Canary Restaurant  43.653323 -79.357883
# 16                  Insomnia Restaurant and Lounge  43.665180 -79.410966
# 17                  Goldstone Noodle Restaurant 金石  43.652278 -79.398039
# 18                                  360 Restaurant  43.642537 -79.387042
# 19                        Ka Chi Korean Restaurant  43.654307 -79.399277
# 20                       Red Chili Thai Restaurant  43.681934 -79.330622
# 21                         Swatow Restaurant 汕頭小食家  43.653866 -79.398334
# 22                          Azure Restaurant & Bar  43.644749 -79.385113
# 23                   Sunshine Caribbean Restaurant  43.680767 -79.338146
# 24             Caribbean Sunset Restaurant and Bar  43.659348 -79.347954
# 25                           Sightlines Restaurant  43.641635 -79.389365
# 26               Kensington Cornerstone Restaurant  43.652803 -79.399958
# 27                                  Lan Restaurant  43.659234 -79.348055
# 28                    Aroma Fine Indian Restaurant  43.646463 -79.389644
# 29              Some Time BBQ Grill Restaurant 碳烤屋  43.655874 -79.393826
# 30                               Makkah Restaurant  43.680642 -79.336613
# 31                  Isabella’s Boutique Restaurant  43.673767 -79.282703
# 32            Sunrise House Korean Restaurant 해뜨는집  43.664183 -79.415746
# 33                     Abugida Restaurant & Lounge  43.682305 -79.327641
# 34                 Hemispheres Restaurant & Bistro  43.654884 -79.385931
# 35                        New Sky Restaurant 小沙田食家  43.655337 -79.398897
# 36                                Union Restaurant  43.645860 -79.419532
# 37                         The Lakeview Restaurant  43.649435 -79.420390
# 38                Imonay House Restaurant 뉴 · 이모네집  43.664123 -79.415815
# 39                      Matisse Restaurant And Bar  43.670574 -79.384856
# 40         Tasty's Caribbean Restaurant & Catering  43.656794 -79.399251
# 41              North-East Chinese Restaurant 華北美食  43.653185 -79.396677
# 42                   Micheal's Restaurant and Deli  43.647289 -79.403493
# 43                         Victor Restaurant & Bar  43.645634 -79.391125
# 44                 Mapo Korean BBQ Restaurant 마포상회  43.664096 -79.416738
# 45                 Lim Ga Ne Korean Restaurant 임가네  43.663945 -79.416882
# 46                            Via Norte Restaurant  43.653732 -79.426303
# 47                Makkalchon Korean Restaurant 맛깔촌  43.744945 -79.296494
# 48                       Korean Village Restaurant  43.664498 -79.414367
# 49     Karaikudi Chettinad South Indian Restaurant  43.756042 -79.276276
#
#     Rating      N                     Type         Short
# 0      NaN    NaN      American Restaurant      American
# 1      8.3   55.0    Vietnamese Restaurant    Vietnamese
# 2      NaN    NaN                      Bar           Bar
# 3      6.8  191.0      American Restaurant      American
# 4      7.7    9.0               Restaurant    Restaurant
# 5      7.7  370.0           Breakfast Spot     Breakfast
# 6      7.3   77.0       Italian Restaurant       Italian
# 7      NaN    NaN       Chinese Restaurant       Chinese
# 8      NaN    NaN              Event Space   Event Space
# 9      6.6  303.0       Dim Sum Restaurant       Dim Sum
# 10     NaN    NaN           Breakfast Spot     Breakfast
# 11     NaN    NaN          Thai Restaurant          Thai
# 12     6.0   72.0       Dim Sum Restaurant       Dim Sum
# 13     7.8  134.0  New American Restaurant  New American
# 14     NaN    NaN       Chinese Restaurant       Chinese
# 15     NaN    NaN           Breakfast Spot     Breakfast
# 16     8.8  441.0               Restaurant    Restaurant
# 17     6.1   91.0             Noodle House       Noodles
# 18     7.3  452.0                 Wine Bar      Wine Bar
# 19     7.2   52.0        Korean Restaurant        Korean
# 20     NaN    NaN          Thai Restaurant          Thai
# 21     7.5  146.0       Chinese Restaurant       Chinese
# 22     5.3   49.0               Restaurant    Restaurant
# 23     NaN    NaN     Caribbean Restaurant     Caribbean
# 24     NaN    NaN               Restaurant    Restaurant
# 25     NaN    NaN      American Restaurant      American
# 26     6.0   32.0           Breakfast Spot     Breakfast
# 27     6.2    8.0    Vietnamese Restaurant    Vietnamese
# 28     7.0   80.0        Indian Restaurant        Indian
# 29     NaN    NaN      Szechuan Restaurant      Szechuan
# 30     6.0   12.0               Restaurant    Restaurant
# 31     7.7   12.0      Japanese Restaurant      Japanese
# 32     8.5   68.0        Korean Restaurant        Korean
# 33     NaN    NaN     Ethiopian Restaurant     Ethiopian
# 34     6.0   18.0      American Restaurant      American
# 35     7.5   55.0       Chinese Restaurant       Chinese
# 36     8.9  240.0  New American Restaurant  New American
# 37     7.2  438.0                    Diner         Diner
# 38     6.6   11.0        Korean Restaurant        Korean
# 39     5.7   17.0               Restaurant    Restaurant
# 40     NaN    NaN     Caribbean Restaurant     Caribbean
# 41     6.2   11.0       Chinese Restaurant       Chinese
# 42     NaN    NaN                      Bar           Bar
# 43     8.1   22.0                      Bar           Bar
# 44     NaN    NaN        Korean Restaurant        Korean
# 45     7.2   31.0        Korean Restaurant        Korean
# 46     NaN    NaN               Restaurant    Restaurant
# 47     8.2   66.0        Korean Restaurant        Korean
# 48     7.6  146.0        Korean Restaurant        Korean
# 49     6.4   56.0        Indian Restaurant        Indian

# %%
df_restaurants.dropna()
# Out:
#                                            Name   Latitude  Longitude  Rating  \
# 1                              Mi Mi Restaurant  43.666293 -79.349079     8.3
# 3                The Hot House Restaurant & Bar  43.648824 -79.373702     6.8
# 4                         Victoria's Restaurant  43.649298 -79.376431     7.7
# 5                             SCHOOL Restaurant  43.637775 -79.424297     7.7
# 6      Gio Rana's Really Really Nice Restaurant  43.663367 -79.330425     7.3
# 9                        Rol San Restaurant 龍笙棧  43.654318 -79.398650     6.6
# 12           Sky Dragon Chinese Restaurant 龍翔酒樓  43.652783 -79.398174     6.0
# 13                        ONE Restaurant/Lounge  43.670809 -79.393272     7.8
# 16               Insomnia Restaurant and Lounge  43.665180 -79.410966     8.8
# 17               Goldstone Noodle Restaurant 金石  43.652278 -79.398039     6.1
# 18                               360 Restaurant  43.642537 -79.387042     7.3
# 19                     Ka Chi Korean Restaurant  43.654307 -79.399277     7.2
# 21                      Swatow Restaurant 汕頭小食家  43.653866 -79.398334     7.5
# 22                       Azure Restaurant & Bar  43.644749 -79.385113     5.3
# 26            Kensington Cornerstone Restaurant  43.652803 -79.399958     6.0
# 27                               Lan Restaurant  43.659234 -79.348055     6.2
# 28                 Aroma Fine Indian Restaurant  43.646463 -79.389644     7.0
# 30                            Makkah Restaurant  43.680642 -79.336613     6.0
# 31               Isabella’s Boutique Restaurant  43.673767 -79.282703     7.7
# 32         Sunrise House Korean Restaurant 해뜨는집  43.664183 -79.415746     8.5
# 34              Hemispheres Restaurant & Bistro  43.654884 -79.385931     6.0
# 35                     New Sky Restaurant 小沙田食家  43.655337 -79.398897     7.5
# 36                             Union Restaurant  43.645860 -79.419532     8.9
# 37                      The Lakeview Restaurant  43.649435 -79.420390     7.2
# 38             Imonay House Restaurant 뉴 · 이모네집  43.664123 -79.415815     6.6
# 39                   Matisse Restaurant And Bar  43.670574 -79.384856     5.7
# 41           North-East Chinese Restaurant 華北美食  43.653185 -79.396677     6.2
# 43                      Victor Restaurant & Bar  43.645634 -79.391125     8.1
# 45              Lim Ga Ne Korean Restaurant 임가네  43.663945 -79.416882     7.2
# 47             Makkalchon Korean Restaurant 맛깔촌  43.744945 -79.296494     8.2
# 48                    Korean Village Restaurant  43.664498 -79.414367     7.6
# 49  Karaikudi Chettinad South Indian Restaurant  43.756042 -79.276276     6.4
#
#         N                     Type         Short
# 1    55.0    Vietnamese Restaurant    Vietnamese
# 3   191.0      American Restaurant      American
# 4     9.0               Restaurant    Restaurant
# 5   370.0           Breakfast Spot     Breakfast
# 6    77.0       Italian Restaurant       Italian
# 9   303.0       Dim Sum Restaurant       Dim Sum
# 12   72.0       Dim Sum Restaurant       Dim Sum
# 13  134.0  New American Restaurant  New American
# 16  441.0               Restaurant    Restaurant
# 17   91.0             Noodle House       Noodles
# 18  452.0                 Wine Bar      Wine Bar
# 19   52.0        Korean Restaurant        Korean
# 21  146.0       Chinese Restaurant       Chinese
# 22   49.0               Restaurant    Restaurant
# 26   32.0           Breakfast Spot     Breakfast
# 27    8.0    Vietnamese Restaurant    Vietnamese
# 28   80.0        Indian Restaurant        Indian
# 30   12.0               Restaurant    Restaurant
# 31   12.0      Japanese Restaurant      Japanese
# 32   68.0        Korean Restaurant        Korean
# 34   18.0      American Restaurant      American
# 35   55.0       Chinese Restaurant       Chinese
# 36  240.0  New American Restaurant  New American
# 37  438.0                    Diner         Diner
# 38   11.0        Korean Restaurant        Korean
# 39   17.0               Restaurant    Restaurant
# 41   11.0       Chinese Restaurant       Chinese
# 43   22.0                      Bar           Bar
# 45   31.0        Korean Restaurant        Korean
# 47   66.0        Korean Restaurant        Korean
# 48  146.0        Korean Restaurant        Korean
# 49   56.0        Indian Restaurant        Indian

# %%
print('Of the', df_restaurants.shape[0], 'restaurants', df_restaurants.dropna().shape[0], 'have been rated.')
# Out:
# Of the 50 restaurants 32 have been rated.

# %%
df_rated = df_restaurants.dropna()

df_rated_type = df_rated.groupby(['Type']).mean()
df_rated_type = df_rated_type.rename_axis(None, axis=1).reset_index()
df_rated_type = df_rated_type.drop(columns=['Latitude', 'Longitude', 'N'])
df_rated_type
# Out:
#                        Type    Rating
# 0       American Restaurant  6.400000
# 1                       Bar  8.100000
# 2            Breakfast Spot  6.850000
# 3        Chinese Restaurant  7.066667
# 4        Dim Sum Restaurant  6.300000
# 5                     Diner  7.200000
# 6         Indian Restaurant  6.700000
# 7        Italian Restaurant  7.300000
# 8       Japanese Restaurant  7.700000
# 9         Korean Restaurant  7.550000
# 10  New American Restaurant  8.350000
# 11             Noodle House  6.100000
# 12               Restaurant  6.700000
# 13    Vietnamese Restaurant  7.250000
# 14                 Wine Bar  7.300000

# %%
# Count number of restaurants by type
df_rated_count = df_rated.groupby(['Type']).count()

# Count number of ratings by type
df_rated_sum = df_rated.groupby(['Type']).sum()

# %%
# Summary of restaurant ratings
df_summary = pd.merge(df_rated_type, df_rated_count, on='Type')
df_summary = pd.merge(df_summary, df_rated_sum, on='Type')
df_summary = df_summary.drop(columns=['Name', 'Latitude_x', 'Longitude_x', 'Rating_y', 'Short', 'Latitude_y', 'Longitude_y', 'Rating'])
df_summary.rename(columns={"Rating_x": "Average Rating", "N_x": "Count", "N_y": 'Total Ratings'}, inplace=True)
df_summary.sort_values(by=['Average Rating', 'Count'], inplace=True, ascending=[False, False])
df_summary['Average Rating'] = round(df_summary['Average Rating'], 2)
df_summary['Total Ratings'] = df_summary['Total Ratings'].apply(lambda x: int(x))
df_summary = df_summary.rename_axis(None, axis=1).reset_index()
df_summary = df_summary.drop(columns=['index'])

df_summary
# Out:
#                        Type  Average Rating  Count  Total Ratings
# 0   New American Restaurant            8.35      2            374
# 1                       Bar            8.10      1             22
# 2       Japanese Restaurant            7.70      1             12
# 3         Korean Restaurant            7.55      6            374
# 4        Italian Restaurant            7.30      1             77
# 5                  Wine Bar            7.30      1            452
# 6     Vietnamese Restaurant            7.25      2             63
# 7                     Diner            7.20      1            438
# 8        Chinese Restaurant            7.07      3            212
# 9            Breakfast Spot            6.85      2            402
# 10               Restaurant            6.70      5            528
# 11        Indian Restaurant            6.70      2            136
# 12      American Restaurant            6.40      2            209
# 13       Dim Sum Restaurant            6.30      2            375
# 14             Noodle House            6.10      1             91

# %%
print('Lowest rating for a restaurant was', min(df_rated['Rating']))
print('Highest rating for a restaurant was', max(df_rated['Rating']))
print('Average rating for a restaurant was', round(np.mean(df_rated['Rating']), 2))

# nan = white
# >= 8 = green
# < 8 and >= 7 = yellow
# < 7 = red

colors_rating = []

for y in df_restaurants['Rating']:
    if np.isnan(y):
        colors_rating.append('white')
    elif y >= 8:
        colors_rating.append('green')
    elif y < 7:
        colors_rating.append('red')
    else:
        colors_rating.append('yellow')
# Out:
# Lowest rating for a restaurant was 5.3
# Highest rating for a restaurant was 8.9
# Average rating for a restaurant was 7.11

# %%
colors_type = colors_rating.copy()

for x in range(len(df_restaurants['Type'])):
    if df_restaurants['Type'][x] == 'New American Restaurant':
        colors_type[x] = 'blue'

# %% [markdown]
# ### Results
#
# It turns out that the type of restaurant with the highest average ratings is the New American Restaurant, and thus it is decided to select opening a New American Restaurant.
#
# For deciding the location of the new restaurant the 50 restaurants comprising the data are plotted onto a map of Toronto. The restaurants are colorcoded with a traffic light scheme so that the restaurants with a rating of 8 or higher are plotted with green dots, restaurants with a rating below 8 but greater than or equal to 7 are represented with a yellow dot, and restaurants with ratings less than 7 are plotted with red dots. The restaurants which have not been rated are plotted with a white dot.
#
# To highlight the locations of the existing New American Restaurants, their dots are given a blue ring so that they can be found on the map.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
i = -1
for lat, lng, type1, name1, rating1 in zip(df_restaurants['Latitude'], df_restaurants['Longitude'], df_restaurants['Type'], df_restaurants['Name'], df_restaurants['Rating']):
    i += 1
    label = '{}, {}, {}'.format(type1, name1, rating1)
    label = folium.Popup(label, parse_html=True)
    color1 = ['red', 'blue']
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color = colors_type[i],
        fill=True,
        fill_color=colors_rating[i],
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It turns out that there is a clustering of lowly rated restaurants in the Chinatown area. This area around the intersection of Dundas Street West and Spadina Avenue seems a suitable site for opening a New American Restaurant. The vicinity of this site already has in total ten restaurants which gives reason to believe that there are also customers in this area. While most of the restaurants are Asian, there is also a Breakfest Spot and a Caribean Restaurant so a New American Restaurant should not be out of place in this location.
#
# The competition, the other New American Restaurants are also suitably far away.
#
# The second map seen below has been centered and zoomed to show the Chinatown area. The five red dots signifying lowly rated restaurants as well as the abscence of green dots representing highly rated restaurants is clearly visibly.

# %%
map_toronto_2 = folium.Map(location=[43.653866, -79.398334], zoom_start=16)

# add markers to map
i = -1
for lat, lng, type1, name1, rating1 in zip(df_restaurants['Latitude'], df_restaurants['Longitude'], df_restaurants['Type'], df_restaurants['Name'], df_restaurants['Rating']):
    i += 1
    label = '{}, {}, {}'.format(type1, name1, rating1)
    label = folium.Popup(label, parse_html=True)
    color1 = ['red', 'blue']
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color = colors_type[i],
        fill=True,
        fill_color=colors_rating[i],
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_2)  
    

map_toronto_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Discussion
#
# Since the number of restaurants in this study was only 50 of which 32 had been rated, all conclusions based on this limited data have to go with some grain of salt, but nevertheless there were two interesting results which stood out. The first one was how highly rated the [New American](https://en.wikipedia.org/wiki/New_American_cuisine) restaurants were. The style of cuisine was unknown to me before this project and my appetitite for trying dishes in this style has been awoken. The other surprise was how low the ratings of the different types of Chinese restaurants around Chinatown were. Whether these genuinely reflect low quality or are a result of disappointment caused by excessively high exceptations is an interesting question. Noteworthily the ratings of Korean restaurants in nearby Koreatown were clearly higher than their Chinese comparisons.
#
#
# ### Conclusion
#
# This limited scope study on restaurants in Toronto demonstrated how useful the Foursquare API can be location based market research. While the scope of this study was small scale, with a little extra effort and incorporation of other data sources on this base a commercial level feasilbility study for a business plan could be performed.
